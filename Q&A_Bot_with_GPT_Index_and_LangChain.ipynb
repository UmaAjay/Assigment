# %% [markdown]
# <a href="https://colab.research.google.com/github/UmaAjay/Assigment/blob/main/Q%26A_Bot_with_GPT_Index_and_LangChain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gpt_index
# !pip install langchain
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.4/204.4 KB 14.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 281.8/281.8 KB 23.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 52.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 KB 6.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 80.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 KB 9.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 95.7 MB/s eta 0:00:00
# ...

# %%
from gpt_index import SimpleDirectoryReader, GPTListIndex, GPTSimpleVectorIndex, LLMPredictor, PromptHelper
from langchain import OpenAI
import sys
#from google.colab import drive
import os

# %%
#drive.mount ('/content/gdrive')

# %%
os.environ["OPENAI_API_KEY"] = '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'

# %%
def construct_index(directory_path):
  # set maximum input size
  max_input_size = 4096
  # set number of output tokens
  num_outputs = 256
  # set maximum chunk overlap
  max_chunk_overlap = 20
  # set chunk size limit
  chunk_size_limit = 600

  prompt_helper = PromptHelper(max_input_size, num_outputs, max_chunk_overlap, chunk_size_limit=chunk_size_limit)

  # define LLM
  llm_predictor = LLMPredictor(llm=OpenAI(temperature=0, model_name="text-ada-001", max_tokens=num_outputs))
  
  documents = SimpleDirectoryReader(directory_path).load_data()
  
  index = GPTSimpleVectorIndex(documents, llm_predictor=llm_predictor, prompt_helper=prompt_helper)
  
  index.save_to_disk('index.json')
  
  return index

# %%
def ask_bot(input_index = 'index.json'):
  index = GPTSimpleVectorIndex.load_from_disk(input_index)
  while True:
    query = input('What do you want to ask the virtual teacher?   \n')
    response = index.query(query, response_mode="compact")
    print ("\nvirtual teacher  says: \n\n" + response.response + "\n\n\n")

# %%
# !wget http://classics.mit.edu/Antoninus/meditations.mb.txt
# Out:
# --2023-02-20 09:33:47--  http://classics.mit.edu/Antoninus/meditations.mb.txt
# Resolving classics.mit.edu (classics.mit.edu)... 18.18.187.25
# Connecting to classics.mit.edu (classics.mit.edu)|18.18.187.25|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘meditations.mb.txt’
#
# meditations.mb.txt      [ <=>                ] 238.35K  --.-KB/s    in 0.05s
#
# 2023-02-20 09:33:48 (4.66 MB/s) - ‘meditations.mb.txt’ saved [244067]

# %%
index = construct_index("/content/")

# %%
ask_bot('index.json')
# Out:
# What do you want to ask the virtual teacher?
# why am i always sad
#
# virtual teacher  says:
#
#
# It is difficult to answer this question without more information about your individual circumstances. However, the context information suggests that it may be helpful to take some time to reflect on your thoughts and feelings and to remember that it is possible to find peace and tranquility within yourself. Consider taking some time to reflect on the arguments presented in the context information and to think about how you can find contentment in the present moment.
#
#
#
# What do you want to ask the virtual teacher?
# how to meditate
#
# virtual teacher  says:
#
#
# ...
